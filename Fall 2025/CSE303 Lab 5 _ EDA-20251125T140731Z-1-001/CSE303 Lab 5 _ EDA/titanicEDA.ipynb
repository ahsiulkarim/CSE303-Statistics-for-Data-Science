# %% [markdown]
# # Part A (Analysis of the Given Dataset)
#
# Dataset Description: Titanic Dataset
#
# ![](https://cdn.pixabay.com/photo/2021/03/04/16/32/ship-6068668_1280.png)
#
# Data Dictionary:
#
#
# 1.	'Survival': 0 = No, 1 = Yes
# 2.	'Pclass': Ticket class 1 = 1st, 2 = 2nd, 3 = 3rd
# 3.	'Sex': Sex
# 4.	'Age': Age in years
# 5.	'SibSp':  siblings/spouses aboard
# 6.	'Parch':  parents/children aboard
# 7.	'Ticket': Ticket number
# 8.	'Fare': Passenger fare
# 9.	'Cabin': Cabin number
# 10.	'Embarked': Port of Embarkation C = Cherbourg, Q = Queenstown, S = Southampton
#
#
# The data has been split into two groups:
# 1.	training set (train.csv)
# 2.	test set     (test.csv)
#
# \\
# The training set should be used to build your machine-learning models.
#
# The test set should be used to see how well your model performs on unseen data.

# %% [markdown]
# ## Dataset Characteristics and Exploratory Data Analysis

# %% [markdown]
# ### Load, view data and show analysis on data. Be creative. Investigate like a detective.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from scipy import stats

# %%
train_data = pd.read_csv("/content/drive/MyDrive/spring2025/spring2025_303/Lab 5/train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/spring2025/spring2025_303/Lab 5/test.csv")
gender_data = pd.read_csv("/content/drive/MyDrive/spring2025/spring2025_303/Lab 5/gender_submission.csv")

# %%
display('Train Data:',train_data.head(), 'Test Data:',test_data.head(), 'Gender Data:',gender_data.head())
# Out:
# 'Train Data:'
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 'Test Data:'
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 'Gender Data:'
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# Merging gender table and test table to dataframe 'gender_test'
left = gender_data
right = test_data

gender_test = pd.merge(left, right, on=["PassengerId"])
gender_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
# Merging the created dataframe 'gender_test' to the existing dataframe 'train_data'
df = pd.concat([train_data, gender_test])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0           A/5 21171    7.2500   NaN        S
# 1        0            PC 17599   71.2833   C85        C
# 2        0    STON/O2. 3101282    7.9250   NaN        S
# 3        0              113803   53.1000  C123        S
# 4        0              373450    8.0500   NaN        S
# ..     ...                 ...       ...   ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
#Show all column names
print(df. columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Overview about Columns, Range, Non-Null Value Counts, Memory Usage and Data Types (#df.dtpyes)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1309 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     1309 non-null   int64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 132.9+ KB

# %%
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
# Count rows and coulums
# Code Here

row = len(df.axes[0])

column = len(df.axes[1])

print("Number of Rows: ", row)
print("Number of Columns: ", column)
# Out:
# Number of Rows:  1309
# Number of Columns:  12

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### Identifying duplicate values

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# #### Identifying missing values

# %%
# Find the amount of missing values in each column


df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# Calculating the percentage of missing values:
missing_value = df.isnull().mean()* 100
print(missing_value)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# dtype: float64

# %% [markdown]
# #### Visualisation of missing data

# %%
# Detect missing values

# Visualisation

import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# #### Dealing with missing values.

# %%
# dropping cabin
df_copy=df
df_copy.pop('Cabin')
df_copy.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
#checking outlier in Age
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers

outliers = find_outliers_IQR(df['Age'])

print("number of outliers: "+ str(len(outliers)))

print("max outlier value: "+ str(outliers.max()))

print("min outlier value: "+ str(outliers.min()))
# Out:
# number of outliers: 9
# max outlier value: 80.0
# min outlier value: 67.0

# %%
#finding mode value for Fare
mode_val=df_copy['Fare'].value_counts()

#replacing null with mode value
df_copy = df_copy.fillna({"Fare": mode_val[0]})

#finding mode value for Emberked
mode_val1=df_copy['Embarked'].value_counts()

#replacing null with mode value
df_copy = df_copy.fillna({"Embarked": mode_val1[0]})
# Out:
# <ipython-input-87-8ac3ad59d94f>:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_copy = df_copy.fillna({"Embarked": mode_val1[0]})

# %%
df_copy.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
#finding median value for Age

med_val = df_copy['Age'].median()

#replacing null with median value
df_copy['Age'] = df_copy['Age'].fillna(med_val)
df_copy.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df_copy.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.503186     0.498854
# std     378.020061     0.484918     0.837836    12.905241     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    22.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    35.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1309.000000
# mean      0.385027    33.283030
# std       0.865560    51.740839
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %%
# Detect missing values

# Visualisation

import missingno as msno
msno.bar(df_copy)
# Out:
# <Axes: >

# %% [markdown]
# **Information about Missing Values and Dataset:**
#
# First, we checked for missing values. In the visualizing missing values section, we plotted a bar chart using 'missingno', where the x-axis contained the features. From the graph, we can see that there are some missing values in the dataset. In the "Identifying Missing Values" step, we counted how many missing values there were in each feature of our dataset. For example, there are 263 missing values in the 'Sex' feature, 1 in 'Fare', 2 in 'Embarked', and 1014 in 'Cabin'. We have 1309 rows and 12 columns.
#
# **Why We Dropped Some Columns:**
#
# As we can see, there is a large number of missing values in the 'Cabin' feature. Since we don’t need the 'Cabin' feature for our model, we decided to drop it.
#
# **Fixing Values in Other Columns:**
#
# **Fixing Age:**
#
# We checked for outliers in this feature and found some. Since the mean is highly affected by outliers, we chose to use the median and filled the null values with the median values, which are not affected by outliers.
#
# **Fixing Embarked and Fare:**
#
# For the 'Embarked' and 'Fare' columns, we replaced the null values with the mode values from the respective columns. Since both of these features had only 1 or 2 missing values, this did not significantly affect the overall dataset.

# %% [markdown]
# ### Analysing Patterns using Visualisations

# %% [markdown]
# The data type of 'Sex' is an object, which will not be visible in a correlation. So, if we like to include the values of the column 'Sex' into the correlation matrix by creating a new column 'Sex_Number' and set the value 'female' to '1' and 'male' to '0'.

# %%
# Creating a new column 'SexNo' with the values '1' for 'female' and '0' for 'male'
df['Sex_Number'] = np.where((df['Sex'] == "female"), 1, 0)
# Checking if the column 'SexNo' has been added
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Sex_Number
# 0      0         A/5 21171   7.2500        S           0
# 1      0          PC 17599  71.2833        C           1
# 2      0  STON/O2. 3101282   7.9250        S           1
# 3      0            113803  53.1000        S           1
# 4      0            373450   8.0500        S           0

# %% [markdown]
# #### Visualization of column correlation (use groupby). Also, plot Heat Map

# %%
df_c = df.copy()

# %%
df_c.drop(columns=['Sex','Name','Ticket','Embarked'],inplace=True)

# %%
# Correlation table including the new column 'SexNo'
correlation = df_c.corr()
correlation
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.020370 -0.038354  0.028814 -0.055224  0.008942
# Survived       -0.020370  1.000000 -0.264710 -0.053695  0.002370  0.108919
# Pclass         -0.038354 -0.264710  1.000000 -0.408106  0.060832  0.018322
# Age             0.028814 -0.053695 -0.408106  1.000000 -0.243699 -0.150917
# SibSp          -0.055224  0.002370  0.060832 -0.243699  1.000000  0.373587
# Parch           0.008942  0.108919  0.018322 -0.150917  0.373587  1.000000
# Fare            0.031428  0.233622 -0.558629  0.178740  0.160238  0.221539
# Sex_Number     -0.013406  0.688371 -0.124617 -0.063645  0.109609  0.213125
#
#                  Fare  Sex_Number
# PassengerId  0.031428   -0.013406
# Survived     0.233622    0.688371
# Pclass      -0.558629   -0.124617
# Age          0.178740   -0.063645
# SibSp        0.160238    0.109609
# Parch        0.221539    0.213125
# Fare         1.000000    0.185523
# Sex_Number   0.185523    1.000000

# %%
# Visualisation of the corralation table


plt.figure(figsize=(12,8), dpi=77)
sns.heatmap(correlation, linecolor='white',linewidths=0.1, annot=True)
plt.title('Correlation Matrix'.upper(), size=19, pad=13)
plt.xlabel('Titanic Data')
plt.ylabel('Titanic Data')
plt.xticks(rotation=33)
plt.show()

# %% [markdown]
# This heatmap has been generated based on the correlation matrix we found earlier. It simply shows how different parameters are related to each other. In other words, we can say that this heatmap is useful for determining how strongly two features are correlated. Based on this relationship, we can decide whether to drop a column or not.
#
# Now, what do the values mean? For example, the feature 'Age' is strongly correlated with itself, which is why the value in the corresponding column is 1, the highest value in a correlation matrix. Now, let's take another example. From the heatmap, we can see that the value for 'Sex_number' and 'Survived' is 0.69, which is high compared to other values in the matrix. This means the two features are highly correlated. Since we are going to predict the survival rate from this dataset, we cannot drop 'Sex_number'; otherwise, it would affect both the dataset and the model.

# %% [markdown]
# #### Visualization of column relationships (Categorical Variables)
#
#
#
# 1.   Comparing two columns using different types of plots
# 2.   Comparing multiple columns using different types of plots

# %% [markdown]
# #####Sex Proportion

# %%
male = (df['Sex'] == 'male').sum()
female = (df['Sex']== 'female').sum()
proportions = [male,female]

plt.figure(figsize=(12,8), dpi=77)
plt.pie(proportions, data=df, labels= ['Males', 'Females'], explode = (0.05,0), startangle=90, autopct='%1.1f%%', shadow=False)
plt.axis('equal')
plt.title("Sex Proportion", size=17, pad=13)
plt.show()

# %% [markdown]
# In this section, we created a pie chart to show the sex proportion of the passengers. That is, how many of the passengers were male and how many were female. We created a pie chart based on their proportions. If we consider the total percentage of the passengers as 100%, from the graph, we can see that 64.4% of the passengers were male, and 35.6% were female.

# %% [markdown]
# #####Age comparision of the people who survived and those who died

# %%
# How many people survived ('Survived' == 0)
survived_data=df.Survived.value_counts().to_frame()
survived_data
# Out:
#           count
# Survived
# 0           815
# 1           494

# %%
pd.pivot_table(df, index="Survived", values=['Pclass','SibSp', 'Parch', 'Fare'])
# Out:
#                Fare     Parch    Pclass     SibSp
# Survived
# 0         23.879124  0.311656  2.467485  0.496933
# 1         48.811497  0.506073  2.010121  0.502024

# %%
# Amount and average age of people who survived compared to those who died.
df.groupby(['Survived']).Age.agg([len,min, max,'mean', 'median'])
# Out:
# <ipython-input-31-8b180973fd3b>:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Survived']).Age.agg([len,min, max,'mean', 'median'])
# <ipython-input-31-8b180973fd3b>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['Survived']).Age.agg([len,min, max,'mean', 'median'])
#           len   min   max       mean  median
# Survived
# 0         815  0.33  74.0  30.510986    28.0
# 1         494  0.17  80.0  28.931079    28.0

# %%
fem_p1_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 0)].Age.median()
fem_p1_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 1)].Age.median()
fem_p1_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 2)].Age.median()
fem_p1_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 1) & (df.SibSp == 3)].Age.median()
fem_p2_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 0)].Age.median()
fem_p2_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 1)].Age.median()
fem_p2_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 2)].Age.median()
fem_p2_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 2) & (df.SibSp == 3)].Age.median()
fem_p3_s0 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 0)].Age.median()
fem_p3_s1 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 1)].Age.median()
fem_p3_s2 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 2)].Age.median()
fem_p3_s3 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 3)].Age.median()
fem_p3_s4 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 4)].Age.median()
fem_p3_s5 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 5)].Age.median()
fem_p3_s8 =df.loc[(df.Sex == 'female') & (df.Pclass == 3) & (df.SibSp == 8)].Age.median()
male_p1_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 0)].Age.median()
male_p1_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 1)].Age.median()
male_p1_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 2)].Age.median()
male_p1_s3 =df.loc[(df.Sex == 'male') & (df.Pclass == 1) & (df.SibSp == 3)].Age.median()
male_p2_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 0)].Age.median()
male_p2_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 1)].Age.median()
male_p2_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 2) & (df.SibSp == 2)].Age.median()
male_p3_s0 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 0)].Age.median()
male_p3_s1 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 1)].Age.median()
male_p3_s2 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 2)].Age.median()
male_p3_s3 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 3)].Age.median()
male_p3_s4 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 4)].Age.median()
male_p3_s5 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 5)].Age.median()
male_p3_s6 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 6)].Age.median()
male_p3_s8 =df.loc[(df.Sex == 'male') & (df.Pclass == 3) & (df.SibSp == 8)].Age.median()

# Filling missing values with average age of women and men in each class
def myfunc(age, pclass, sex, SibSp):
    if pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 0:
        age=fem_p1_s0
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 1:
        age=fem_p1_s1
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 2:
        age=fem_p1_s2
    elif pd.isnull(age) and pclass==1 and sex == 'female' and SibSp == 3:
        age=fem_p1_s3
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 0:
        age=fem_p2_s0
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 1:
        age=fem_p2_s1
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 2:
        age=fem_p2_s2
    elif pd.isnull(age) and pclass==2 and sex == 'female' and SibSp == 3:
        age=fem_p2_s3
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 0:
        age=fem_p3_s0
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 1:
        age=fem_p3_s1
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 2:
        age=fem_p3_s2
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 3:
        age=fem_p3_s3
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 4:
        age=fem_p3_s4
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 5:
        age=fem_p3_s5
    elif pd.isnull(age) and pclass==3 and sex == 'female' and SibSp == 8:
        age=df.Age.median()
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 0:
        age=male_p1_s0
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 1:
        age=male_p1_s1
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 2:
        age=male_p1_s2
    elif pd.isnull(age) and pclass==1 and sex == 'male' and SibSp == 3:
        age=male_p1_s3
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 0:
        age=male_p2_s0
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 1:
        age=male_p2_s1
    elif pd.isnull(age) and pclass==2 and sex == 'male' and SibSp == 2:
        age=male_p2_s2
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 0:
        age=male_p3_s0
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 1:
        age=male_p3_s1
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 2:
        age=male_p3_s2
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 3:
        age=male_p3_s3
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 4:
        age=male_p3_s4
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 5:
        age=male_p3_s5
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 6:
        age=male_p3_s6
    elif pd.isnull(age) and pclass==3 and sex == 'male' and SibSp == 8:
        age=male_p3_s8
    else:
        age=age
    return age
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
# Creating a new columns 'Age_Filled_Na' with the new average age values
df['Age_Filled'] = df.apply(lambda x: myfunc(x['Age'], x['Pclass'], x['Sex'], x['SibSp']), axis=1)

# %%
# Age comparision of the people who survived and those who died using a boxplot.
plt.figure(figsize=(10,8), dpi=77)
sns.boxplot(x="Survived", y="Age_Filled", data=df)
plt.title("Comparison: Age of People who died / survived", size=17, pad=13)
plt.ylabel('Age')
plt.xlabel(' ')
plt.xticks([0, 1], ['Not Survived', 'Survived'])
plt.show()

# %% [markdown]
# This section aims to explore the relationship between survival rate and age. The plot above shows both survived and not survived passengers across different ages. As we can see from the boxplot, there are some outliers. Most of the data fall within the range of 20 to 40 years. Although, in general, the passengers who did not survive tend to be slightly older than those who survived. The actual dataset contained a lot of null values, which we filled using the median.

# %%
plt.figure(figsize=(10,8), dpi=77)
sns.barplot(x="Sex", y="Survived", data=df)
plt.title("Survivors - Male & Female", size=17, pad=13 )
plt.show()

# %% [markdown]
# In this section, we compared the survival rates of males and females using a bar chart. From the plot, we can clearly see that a significantly larger number of females survived the disaster. Later, we ran some code to check the survival rate based on sex. The results showed that about 82.62% of females survived, while only 12.93% of males survived. This makes sense because, during the disaster, women and children were evacuated to safety first. Therefore, the survival rate of females should be higher than that of males.

# %% [markdown]
# #####Comparison: Survivors - Male & Female

# %%
plt.figure(figsize=(10,8), dpi=77)
sns.countplot(x=df['Sex'],hue=df['Survived'])
plt.title("Comparison: Survivors - Male & Female", size=17, pad= 13)
plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 12})
plt.show()

# %% [markdown]
# This is a comparison plot showing the number of males and females who survived and did not survive. From the graph, we can see that the number of males who did not survive is significantly high, with only a small number of men surviving the accident. On the other hand, the number of female survivors is relatively high, especially since the number of male survivors is low. Similarly, the number of females who did not survive is small. Both the survivors and non-survivors are shown for both sexes.

# %%
# Find percentage of women who survived

print('%.2f'%((df['Survived'][df['Sex']=='female']).mean()*100) ,"%")
# Out:
# 82.62 %

# %%
# Find percentage of men who survived

print('%.2f'%((df['Survived'][df['Sex']=='male']).mean()*100) ,"%")
# Out:
# 12.93 %

# %% [markdown]
# #####Compares the chance of survival for each ticket class

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df.groupby(['Pclass', 'Survived']).Age.agg([len])
# Out:
#                  len
# Pclass Survived
# 1      0         137
#        1         186
# 2      0         160
#        1         117
# 3      0         518
#        1         191

# %%
plt.figure(figsize=(10,8), dpi=77)
sns.barplot(x="Pclass", y="Survived", data=df)
plt.title("Chance of Survival for each Ticket Class", size=17, pad=13)
plt.show()

# %%
# Survived and not survived compared for each ticket class
plt.figure(figsize=(10,8), dpi=77)
sns.countplot(x=df['Pclass'],hue=df['Survived'])
plt.title("Comparison: Survivors - Ticket Class", size=17, pad=13)
plt.legend(['Not Survived', 'Survived'], loc='upper left', prop={'size': 12})
plt.show()

# %% [markdown]
# In this section, we examined whether ticket class has any impact on the survival rate. In our dataset, there are three ticket classes. In the plot above, there are six bars representing the number of survivors and non-survivors in each class. From the plot, we can clearly see that both the number of survivors and non-survivors are high in class 3. However, compared to the other classes, most people in class 3 did not survive. The lowest death rate is observed in class 1, which makes sense because class 1 passengers have more privileges than passengers in other classes. Additionally, these passengers had access to the most secure and comfortable spaces.

# %% [markdown]
# #####Chance of Survival for Passengers with Parents or Children

# %%
# Amount and average age of women and man of each class who survived compared to those who died.
df.groupby(['Sex','Survived', 'Pclass']).Age.agg([len,min, max,'mean'])
# Out:
# <ipython-input-43-29722babbf43>:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Sex','Survived', 'Pclass']).Age.agg([len,min, max,'mean'])
# <ipython-input-43-29722babbf43>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['Sex','Survived', 'Pclass']).Age.agg([len,min, max,'mean'])
#                         len    min   max       mean
# Sex    Survived Pclass
# female 0        1         3   2.00  50.0  25.666667
#                 2         6  24.00  57.0  36.000000
#                 3        72   2.00  48.0  23.818182
#        1        1       141  14.00  76.0  37.300000
#                 2       100   0.92  60.0  26.973402
#                 3       144   0.17  63.0  21.259485
# male   0        1       134   6.00  71.0  42.752252
#                 2       154   2.00  70.0  32.367133
#                 3       446   0.33  74.0  26.412894
#        1        1        45   0.92  80.0  36.248000
#                 2        17   0.67  62.0  16.022000
#                 3        47   0.42  45.0  22.274211

# %%
df['Parch'].value_counts().to_frame()
# Out:
#        count
# Parch
# 0       1002
# 1        170
# 2        113
# 3          8
# 5          6
# 4          6
# 6          2
# 9          2

# %%
plt.figure(figsize=(12,6), dpi=77)
sns.barplot(x="Parch", y="Survived", data=df)
plt.title("Chance of Survival for Passengers with Parents or Children", size=17, pad=13)
plt.xlabel('Number of Parents / Children')
plt.show()

# %%
plt.figure(figsize=(12,8), dpi=77)
sns.countplot(x=df['Parch'],hue=df['Survived'])
plt.title("Survived - Parents or Children", size=17, pad=12)
plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 12})
plt.xlabel('Parents / Children')
plt.show()

# %%
# Age of people with parents or children
df.groupby(['Parch','Survived']).Age.agg([len, min, max])
# Out:
# <ipython-input-47-082e46f69a94>:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['Parch','Survived']).Age.agg([len, min, max])
# <ipython-input-47-082e46f69a94>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['Parch','Survived']).Age.agg([len, min, max])
#                 len    min   max
# Parch Survived
# 0     0         670  11.00  74.0
#       1         332   5.00  80.0
# 1     0          77   0.75  70.0
#       1          93   0.42  64.0
# 2     0          53   0.33  58.0
#       1          60   0.17  64.0
# 3     0           3  16.00  61.0
#       1           5  24.00  54.0
# 4     0           4  29.00  64.0
#       1           2  60.00  60.0
# 5     0           5  39.00  41.0
#       1           1  38.00  38.0
# 6     0           2  40.00  43.0
# 9     0           1    NaN   NaN
#       1           1    NaN   NaN

# %% [markdown]
# This section discusses the relationship between survival and passengers who were traveling with their children or parents. In this plot, we can find 8 categories based on the number of parents or children a passenger was traveling with. From the plot, it is clear that most of the people traveling without their parents or children survived. The same is true for those who did not survive; most of them were also traveling alone. However, the chances of survival paint a different picture. From the survival probability plot, we can see that those who were traveling alone had much lower chances of survival.
#
# Passengers who had one parent or child survived at a moderate rate, falling somewhere in between high and low survival. For this category, though, the survival rate is noticeably higher compared to the rate of non-survivors. The probability graph also supports this, showing that their chances of survival were indeed higher.
#
# The same general trend applies to other categories as well. Categories 6 and 9 have only two values, so it is difficult to draw conclusions about them due to the limited data in these categories.

# %%
df.SibSp.value_counts()
# Out:
# SibSp
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: count, dtype: int64

# %%
df.groupby(['SibSp','Survived']).Age.agg([len, 'mean'])
# Out:
#                 len       mean
# SibSp Survived
# 0     0         593  31.603537
#       1         298  29.689549
# 1     0         153  33.509398
#       1         166  28.840204
# 2     0          23  23.950000
#       1          19  23.093750
# 3     0          15  11.181818
#       1           5  27.600000
# 4     0          18   7.222222
#       1           4  15.750000
# 5     0           5  10.200000
#       1           1  10.000000
# 8     0           8  14.500000
#       1           1        NaN

# %%
# This barplot compares the chance of survival within a category
plt.figure(figsize=(12,6), dpi=77)
sns.barplot(x="SibSp", y="Survived", data=df)
plt.title("Chance of Survival for Passengers with Siblings or Spouses", size=17, pad=13)
plt.xlabel('Number of Siblings / Spouses')
plt.show()

# %%
plt.figure(figsize=(12,8), dpi=77)
sns.countplot(x=df['SibSp'],hue=df['Survived'])
plt.title("Survived - Siblings or Spouses", size=17, pad=13)
plt.xlabel('Siblings / Spouses')
plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 12})
plt.show()

# %%
df.groupby(['SibSp','Survived']).Age.agg([len, min, max, 'mean'])
# Out:
# <ipython-input-52-d05882797b23>:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(['SibSp','Survived']).Age.agg([len, min, max, 'mean'])
# <ipython-input-52-d05882797b23>:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['SibSp','Survived']).Age.agg([len, min, max, 'mean'])
#                 len    min   max       mean
# SibSp Survived
# 0     0         593   0.33  74.0  31.603537
#       1         298   0.42  80.0  29.689549
# 1     0         153   0.75  70.0  33.509398
#       1         166   0.17  76.0  28.840204
# 2     0          23   9.00  44.0  23.950000
#       1          19   0.75  59.0  23.093750
# 3     0          15   2.00  31.0  11.181818
#       1           5  23.00  33.0  27.600000
# 4     0          18   1.00  16.0   7.222222
#       1           4   3.00  38.0  15.750000
# 5     0           5   1.00  16.0  10.200000
#       1           1  10.00  10.0  10.000000
# 8     0           8  14.50  14.5  14.500000
#       1           1    NaN   NaN        NaN

# %% [markdown]
# In this section, we explore the relationship between survival rate and passengers traveling with siblings or spouses, including survival chances. From the survival chance plot, we can see that those traveling with one sibling or spouse had a high survival chance. However, in the actual survival graph, the survival rate for this group is not as high as that of people traveling alone (i.e., with 0 siblings/spouse). People who traveled alone had a higher survival rate compared to those who died in the same category. On the other hand, in the actual survival graph, those who traveled alone represent the highest number of both survivors and non-survivors. The chances of survival for this category, however, are moderately low, according to the survival chance graph.
#
# The lowest chance of survival was observed for those traveling with 8 siblings or spouses. From the actual survival graph, we can see that no one from this category survived the accident.
#
# Those traveling with 2 siblings or spouses had a moderate chance of survival. From the actual survival graph, we can see that the non-survival rate is higher than the survival rate for this category.
#
# The survival chances gradually decreased for the next three categories (those with 3, 4, or 5 siblings or spouses). The actual survival graph shows a similar trend for these categories, with a low survival rate for those with 3 or 4 siblings/spouses, and no survivors in the category of 5 siblings/spouses.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  Sex_Number  Age_Filled
# 0      0         A/5 21171   7.2500        S           0        22.0
# 1      0          PC 17599  71.2833        C           1        38.0
# 2      0  STON/O2. 3101282   7.9250        S           1        26.0
# 3      0            113803  53.1000        S           1        35.0
# 4      0            373450   8.0500        S           0        35.0

# %% [markdown]
# #####Average Age of Passengers with Siblings and  Parents or Children

# %%
plt.figure(figsize=(12,6), dpi=77)
sns.barplot(x="SibSp", y="Age", data=df_copy)
plt.title('Average Age of Passengers with Siblings', size=17, pad=13)
plt.xlabel('Siblings')
plt.show()

# %%
plt.figure(figsize=(12,8), dpi=77)
sns.boxplot(x="Parch", y="Age", data=df_copy)
plt.title('Age of Passengers with Parents or Children', size=17, pad=13)
plt.xlabel('Parents / Children')
plt.show()

# %%
plt.figure(figsize=(12,6), dpi=77)
sns.barplot(x="Parch", y="Age", data=df_copy)
plt.title('Average Age of Passengers with Parents or Children', size=17, pad=12)
plt.xlabel('Parents / Children')
plt.show()

# %% [markdown]
# #####Age of Passengers for each Ticket Class

# %%
plt.figure(figsize=(12,6), dpi=77)
sns.boxplot(x="Pclass", y="Age", data=df_copy)
plt.title('Age of Passengers for each Ticket Class', size=17, pad=13)
plt.xlabel('Ticket Class')
plt.show()

# %% [markdown]
# Here is a boxplot showing the ages of passengers for each ticket class. From the plot, we can see that the age range in the 1st class is quite large, ranging from 28 to 48 years. This suggests that people in first class were generally older. It also has some outliers. The 2nd class passengers have a smaller age range, roughly between 22 and 36 years, indicating that people in this class were younger. The same trend applies to the 3rd class, where the age range falls between 20 and 34 years, suggesting that they were also younger. Both of these classes have a relatively high number of outliers.

# %% [markdown]
# #####Comparing multiple columns

# %%
# Comparison of Pclass, Age, Sex and Survivors
g = sns.FacetGrid(df_copy, col='Survived', row='Pclass', sharey=False, ylim=(0,300), hue='Sex', height=7)
g.map_dataframe(sns.scatterplot, x='Age', y='Fare')
g.set_axis_labels('Age', 'Fare')
g.add_legend()
# g.set_titles(col_template='', row_template='')
plt.show()

# %%
# Comparison of Parch, Age, Sex and Survivors
g = sns.FacetGrid(df_copy, col='Survived', row='SibSp', sharey=False, ylim=(0,300), hue='Sex', height=7)
g.map_dataframe(sns.scatterplot, x='Age', y='Fare')
g.set_axis_labels('Age', 'Fare')
g.add_legend()
# g.set_titles(col_template='', row_template='')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.histplot(df_copy.Fare)
plt.title('Fares Paid', size=17, pad=13)
plt.show()

# %%
fig, axs = plt.subplots(figsize=(22, 9))
sns.countplot(x='Fare', hue='Survived', data=df_copy)
plt.xlabel('Fare', size=16, labelpad=10)
plt.ylabel('Count', size=15, labelpad=10)
plt.tick_params(axis='x', labelsize=13)
plt.tick_params(axis='y', labelsize=15)
plt.legend(['Not Survived', 'Survived'], loc='upper right', prop={'size': 15})
plt.title('Survial compared to Fare', size=20, y=1, pad=13)
plt.show()

# %% [markdown]
# ##Data Preprocessing

# %% [markdown]
# For encoding categorical variables you can use pandas (get_dummies).
#
# Convert categorical variable into dummy/indicator variables.
#
# Learn More:
#
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.get_dummies.html

# %% [markdown]
# **Examples**

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train1 = train_data.copy()


train1.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)


train1.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data1 = train1.copy()
data1 = pd.get_dummies(data1)

data1.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500       False      True
# 1         1       1  38.0      1      0  71.2833        True     False
# 2         1       3  26.0      0      0   7.9250        True     False
# 3         1       1  35.0      1      0  53.1000        True     False
# 4         0       3  35.0      0      0   8.0500       False      True
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0       False       False        True
# 1        True       False       False
# 2       False       False        True
# 3       False       False        True
# 4       False       False        True

# %% [markdown]
# **Now use the given dataset and perform the data preprocessing steps:**

# %%
#all data
data1
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500       False      True
# 1           1       1  38.0      1      0  71.2833        True     False
# 2           1       3  26.0      0      0   7.9250        True     False
# 3           1       1  35.0      1      0  53.1000        True     False
# 4           0       3  35.0      0      0   8.0500       False      True
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 886         0       2  27.0      0      0  13.0000       False      True
# 887         1       1  19.0      0      0  30.0000        True     False
# 888         0       3   NaN      1      2  23.4500        True     False
# 889         1       1  26.0      0      0  30.0000       False      True
# 890         0       3  32.0      0      0   7.7500       False      True
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False        True
# 4         False       False        True
# ..          ...         ...         ...
# 886       False       False        True
# 887       False       False        True
# 888       False       False        True
# 889        True       False       False
# 890       False        True       False
#
# [891 rows x 11 columns]

# %%
#duplicate data
duplicate = data1[data1.duplicated()]
duplicate
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 47          1       3   NaN      0      0   7.7500        True     False
# 76          0       3   NaN      0      0   7.8958       False      True
# 77          0       3   NaN      0      0   8.0500       False      True
# 87          0       3   NaN      0      0   8.0500       False      True
# 95          0       3   NaN      0      0   8.0500       False      True
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 870         0       3  26.0      0      0   7.8958       False      True
# 877         0       3  19.0      0      0   7.8958       False      True
# 878         0       3   NaN      0      0   7.8958       False      True
# 884         0       3  25.0      0      0   7.0500       False      True
# 886         0       2  27.0      0      0  13.0000       False      True
#
#      Embarked_C  Embarked_Q  Embarked_S
# 47        False        True       False
# 76        False       False        True
# 77        False       False        True
# 87        False       False        True
# 95        False       False        True
# ..          ...         ...         ...
# 870       False       False        True
# 877       False       False        True
# 878       False       False        True
# 884       False       False        True
# 886       False       False        True
#
# [111 rows x 11 columns]

# %%
#after dropping duplicate data
data1.drop_duplicates(inplace=True)
data1
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.0      1      0   7.2500       False      True
# 1           1       1  38.0      1      0  71.2833        True     False
# 2           1       3  26.0      0      0   7.9250        True     False
# 3           1       1  35.0      1      0  53.1000        True     False
# 4           0       3  35.0      0      0   8.0500       False      True
# ..        ...     ...   ...    ...    ...      ...         ...       ...
# 885         0       3  39.0      0      5  29.1250        True     False
# 887         1       1  19.0      0      0  30.0000        True     False
# 888         0       3   NaN      1      2  23.4500        True     False
# 889         1       1  26.0      0      0  30.0000       False      True
# 890         0       3  32.0      0      0   7.7500       False      True
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0         False       False        True
# 1          True       False       False
# 2         False       False        True
# 3         False       False        True
# 4         False       False        True
# ..          ...         ...         ...
# 885       False        True       False
# 887       False       False        True
# 888       False       False        True
# 889        True       False       False
# 890       False        True       False
#
# [780 rows x 11 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 780 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    780 non-null    int64
#  1   Pclass      780 non-null    int64
#  2   Age         676 non-null    float64
#  3   SibSp       780 non-null    int64
#  4   Parch       780 non-null    int64
#  5   Fare        780 non-null    float64
#  6   Sex_female  780 non-null    bool
#  7   Sex_male    780 non-null    bool
#  8   Embarked_C  780 non-null    bool
#  9   Embarked_Q  780 non-null    bool
#  10  Embarked_S  780 non-null    bool
# dtypes: bool(5), float64(2), int64(4)
# memory usage: 46.5 KB
